# %%
import pandas as pd

# %%
Newdata = pd.read_excel("C:/Users/Green/Documents/New_data.xlsx")
Newdata
# Out:
#     Student_ID      Name     Age   Gender  Score Enrollment_Date  \
# 0          NaN       Eve  twenty        M    NaN             NaN
# 1          NaN     David      22     Male     75      2021/01/01
# 2        S0003       Eve      22        F  sixty             NaN
# 3        S0004     David      22   Female    200      2021-07-32
# 4        S0005     Alice      21  Unknown     50      03-20-2021
# ..         ...       ...     ...      ...    ...             ...
# 195      S0196       Bob      19        F     60      2021-02-15
# 196      S0197     frank      23     male     45      03-20-2021
# 197      S0198       Eve      21  Unknown     60      2021/01/01
# 198      S0199     Alice      20        M     70      2021-07-32
# 199      S0200       Eve     NaN   FEMALE     65      2021/01/01
#
#                Email           Phone        Department
# 0       eve@mail.com  +2348012345678      Data Science
# 1                NaN             NaN  Computer Science
# ...

# %% [markdown]
# # Cleaning Data

# %%
Dup = Newdata.copy()
Dup
# Out:
#     Student_ID      Name     Age   Gender  Score Enrollment_Date  \
# 0          NaN       Eve  twenty        M    NaN             NaN
# 1          NaN     David      22     Male     75      2021/01/01
# 2        S0003       Eve      22        F  sixty             NaN
# 3        S0004     David      22   Female    200      2021-07-32
# 4        S0005     Alice      21  Unknown     50      03-20-2021
# ..         ...       ...     ...      ...    ...             ...
# 195      S0196       Bob      19        F     60      2021-02-15
# 196      S0197     frank      23     male     45      03-20-2021
# 197      S0198       Eve      21  Unknown     60      2021/01/01
# 198      S0199     Alice      20        M     70      2021-07-32
# 199      S0200       Eve     NaN   FEMALE     65      2021/01/01
#
#                Email           Phone        Department
# 0       eve@mail.com  +2348012345678      Data Science
# 1                NaN             NaN  Computer Science
# ...

# %%
Dup.info()
Dup. describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Student_ID       189 non-null    object
#  1   Name             173 non-null    object
#  2   Age              187 non-null    object
#  3   Gender           176 non-null    object
#  4   Score            189 non-null    object
#  5   Enrollment_Date  162 non-null    object
#  6   Email            174 non-null    object
#  7   Phone            164 non-null    object
#  8   Department       172 non-null    object
# dtypes: object(9)
# memory usage: 14.2+ KB
#        Student_ID   Name  Age Gender  Score Enrollment_Date  \
# count         189    173  187    176    189             162
# unique        189     10    9      7     10               5
# top         S0003  David   22   Male     50      2021/13/01
# freq            1     22   32     33     27              38
#
# ...

# %%
Dup.shape
# Out:
# (200, 9)

# %%
Dup.columns
# Out:
# Index(['Student_ID', 'Name', 'Age', 'Gender', 'Score', 'Enrollment_Date',
#        'Email', 'Phone', 'Department'],
#       dtype='object')

# %%
Dup.isnull().sum()
# Out:
# Student_ID         11
# Name               27
# Age                13
# Gender             24
# Score              11
# Enrollment_Date    38
# Email              26
# Phone              36
# Department         28
# dtype: int64

# %% [markdown]
# # Sorting Data

# %%
Dup.drop_duplicates()
# Out:
#     Student_ID      Name     Age   Gender  Score Enrollment_Date  \
# 0          NaN       Eve  twenty        M    NaN             NaN
# 1          NaN     David      22     Male     75      2021/01/01
# 2        S0003       Eve      22        F  sixty             NaN
# 3        S0004     David      22   Female    200      2021-07-32
# 4        S0005     Alice      21  Unknown     50      03-20-2021
# ..         ...       ...     ...      ...    ...             ...
# 195      S0196       Bob      19        F     60      2021-02-15
# 196      S0197     frank      23     male     45      03-20-2021
# 197      S0198       Eve      21  Unknown     60      2021/01/01
# 198      S0199     Alice      20        M     70      2021-07-32
# 199      S0200       Eve     NaN   FEMALE     65      2021/01/01
#
#                Email           Phone        Department
# 0       eve@mail.com  +2348012345678      Data Science
# 1                NaN             NaN  Computer Science
# ...

# %%
Dup.isnull().sum()
# Out:
# Student_ID         11
# Name               27
# Age                13
# Gender             24
# Score              11
# Enrollment_Date    38
# Email              26
# Phone              36
# Department         28
# dtype: int64

# %%
Dup.dropna()
# Out:
#     Student_ID      Name     Age   Gender Score Enrollment_Date  \
# 3        S0004     David      22   Female   200      2021-07-32
# 5        S0006     HeNry      30   Female    80      03-20-2021
# 7        S0008     HeNry      22     Male    80      2021-02-15
# 8        S0009     David      21     Male    80      2021/01/01
# 14       S0015     HeNry  twenty   FEMALE    80      2021-07-32
# ..         ...       ...     ...      ...   ...             ...
# 181      S0182     David      22     male    75      2021-07-32
# 182      S0183     jack       23     Male    70      03-20-2021
# 184      S0185    Grace       18     male    75      03-20-2021
# 196      S0197     frank      23     male    45      03-20-2021
# 197      S0198       Eve      21  Unknown    60      2021/01/01
#
#                     Email           Phone        Department
# 3         alice@gmail.com  +2348012345678      Comp Science
# 5    charlie[at]yahoo.com   080-1234-5678               ENG
# ...

# %%
Dup["Enrollment_Date"] = pd.to_datetime(Dup["Enrollment_Date"], errors="coerce")   # convert to datetime
Dup
# Out:
#     Student_ID      Name     Age   Gender  Score Enrollment_Date  \
# 0          NaN       Eve  twenty        M    NaN             NaT
# 1          NaN     David      22     Male     75      2021-01-01
# 2        S0003       Eve      22        F  sixty             NaT
# 3        S0004     David      22   Female    200             NaT
# 4        S0005     Alice      21  Unknown     50             NaT
# ..         ...       ...     ...      ...    ...             ...
# 195      S0196       Bob      19        F     60             NaT
# 196      S0197     frank      23     male     45             NaT
# 197      S0198       Eve      21  Unknown     60      2021-01-01
# 198      S0199     Alice      20        M     70             NaT
# 199      S0200       Eve     NaN   FEMALE     65      2021-01-01
#
#                Email           Phone        Department
# 0       eve@mail.com  +2348012345678      Data Science
# 1                NaN             NaN  Computer Science
# ...

# %%
Dup["Age"] = Dup["Age"].astype("int", errors="ignore")       # convert to integer
Dup
# Out:
#     Student_ID      Name     Age   Gender  Score Enrollment_Date  \
# 0          NaN       Eve  twenty        M    NaN             NaT
# 1          NaN     David      22     Male     75      2021-01-01
# 2        S0003       Eve      22        F  sixty             NaT
# 3        S0004     David      22   Female    200             NaT
# 4        S0005     Alice      21  Unknown     50             NaT
# ..         ...       ...     ...      ...    ...             ...
# 195      S0196       Bob      19        F     60             NaT
# 196      S0197     frank      23     male     45             NaT
# 197      S0198       Eve      21  Unknown     60      2021-01-01
# 198      S0199     Alice      20        M     70             NaT
# 199      S0200       Eve     NaN   FEMALE     65      2021-01-01
#
#                Email           Phone        Department
# 0       eve@mail.com  +2348012345678      Data Science
# 1                NaN             NaN  Computer Science
# ...

# %%
print(Dup['Age'])
# Out:
# 0      twenty
# 1          22
# 2          22
# 3          22
# 4          21
#         ...
# 195        19
# 196        23
# 197        21
# 198        20
# 199       NaN
# Name: Age, Length: 200, dtype: object

# %%
Dup["Age"].describe()
# Out:
# count     187
# unique      9
# top        22
# freq       32
# Name: Age, dtype: int64

# %%
Dup.fillna
# Out:
# <bound method NDFrame.fillna of     Student_ID      Name     Age   Gender  Score Enrollment_Date  \
# 0          NaN       Eve  twenty        M    NaN             NaT
# 1          NaN     David      22     Male     75      2021-01-01
# 2        S0003       Eve      22        F  sixty             NaT
# 3        S0004     David      22   Female    200             NaT
# 4        S0005     Alice      21  Unknown     50             NaT
# ..         ...       ...     ...      ...    ...             ...
# 195      S0196       Bob      19        F     60             NaT
# 196      S0197     frank      23     male     45             NaT
# 197      S0198       Eve      21  Unknown     60      2021-01-01
# 198      S0199     Alice      20        M     70             NaT
# 199      S0200       Eve     NaN   FEMALE     65      2021-01-01
#
#                Email           Phone        Department
# 0       eve@mail.com  +2348012345678      Data Science
# ...

# %%
Dup.dropna(inplace = True)
Dup
# Out:
#     Student_ID      Name Age   Gender  Score Enrollment_Date  \
# 8        S0009     David  21     Male     80      2021-01-01
# 31       S0032     David  30  Unknown     80      2021-01-01
# 48       S0049   Charlie  23     male    200      2021-01-01
# 57       S0058     frank  19        F    200      2021-01-01
# 68       S0069     Alice  19   Female     70      2021-01-01
# 91       S0092     Alice  22        F  sixty      2021-01-01
# 96       S0097     jack   23     male     50      2021-01-01
# 131      S0132     David  19        F     70      2021-01-01
# 133      S0134   Charlie  30   FEMALE     55      2021-01-01
# 137      S0138     frank  18   FEMALE    200      2021-01-01
# 145      S0146     Alice  22     Male     60      2021-01-01
# 150      S0151       IVY  23        M  sixty      2021-01-01
# 154      S0155    Grace   22     male     80      2021-01-01
# 163      S0164     Alice  23        M     70      2021-01-01
# ...

# %%
Dup['Age'] = Dup['Age'].astype('Int64') 
Dup
# Convert Age to nullable integar type
# Out:
#     Student_ID      Name  Age   Gender  Score Enrollment_Date  \
# 8        S0009     David   21     Male     80      2021-01-01
# 31       S0032     David   30  Unknown     80      2021-01-01
# 48       S0049   Charlie   23     male    200      2021-01-01
# 57       S0058     frank   19        F    200      2021-01-01
# 68       S0069     Alice   19   Female     70      2021-01-01
# 91       S0092     Alice   22        F  sixty      2021-01-01
# 96       S0097     jack    23     male     50      2021-01-01
# 131      S0132     David   19        F     70      2021-01-01
# 133      S0134   Charlie   30   FEMALE     55      2021-01-01
# 137      S0138     frank   18   FEMALE    200      2021-01-01
# 145      S0146     Alice   22     Male     60      2021-01-01
# 150      S0151       IVY   23        M  sixty      2021-01-01
# 154      S0155    Grace    22     male     80      2021-01-01
# 163      S0164     Alice   23        M     70      2021-01-01
# ...

# %%
# Convert Score to nullable integar type 

Dup['Score'] = Dup['Score'].astype('Int64')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Green\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\arrays\integer.py:53, in IntegerDtype._safe_cast(cls, values, dtype, copy)
#      52 try:
# ---> 53     return values.astype(dtype, casting="safe", copy=copy)
#      54 except TypeError as err:
#
# TypeError: Cannot cast array data from dtype('O') to dtype('int64') according to the rule 'safe'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 3
#       1 # Convert Score to nullable integar type
# ----> 3 Dup['Score'] = Dup['Score'].astype('Int64')
#
# File c:\Users\Green\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:6662, in NDFrame.astype(self, dtype, copy, errors)
# ...

# %%
# Generate new IDs where missing
missing_mask = Dup["Student_ID"].isna()
new_ids = ["S" + str(i+1).zfill(4) for i in Dup.index[missing_mask]]
Dup.loc[missing_mask, "Student_ID"] = new_ids
Dup
# Out:
#     Student_ID      Name  Age  Gender  Score Enrollment_Date  \
# 8        S0009     David   21    Male     80      2021-01-01
# 31       S0032     David   30   Other     80      2021-01-01
# 48       S0049   Charlie   23    male    200      2021-01-01
# 57       S0058     frank   19  Female    200      2021-01-01
# 68       S0069     Alice   19  Female     70      2021-01-01
# 91       S0092     Alice   22  Female  sixty      2021-01-01
# 96       S0097     jack    23    male     50      2021-01-01
# 131      S0132     David   19  Female     70      2021-01-01
# 133      S0134   Charlie   30  FEMALE     55      2021-01-01
# 137      S0138     frank   18  FEMALE    200      2021-01-01
# 145      S0146     Alice   22    Male     60      2021-01-01
# 150      S0151       IVY   23    Male  sixty      2021-01-01
# 154      S0155    Grace    22    male     80      2021-01-01
# 163      S0164     Alice   23    Male     70      2021-01-01
# ...

# %%
Dup["Gender"] = Dup["Gender"].replace({
    "M": "Male",
    "F": "Female",
    "Unknown": "Other"
    })     # Standardise gender entries
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 Dup["Gender"] = Dup["Gender"].replace({
#       2     "M": "Male",
#       3     "F": "Female",
#       4     "Unknown": "Other"
#       5     })     # Standardise gender entries
#
# NameError: name 'Dup' is not defined

# %% [markdown]
# # [~] Not Operator AKA Not In

# %%
Dup.loc[~Dup["Phone"].astype(str).str.match(r'^\+?\d{11,15}$', na=True), "Phone"] = None
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 Dup.loc[~Dup["Phone"].astype(str).str.match(r'^\+?\d{11,15}$', na=True), "Phone"] = None
#
# NameError: name 'Dup' is not defined

# %%
Dup.loc[Dup[~"Email"].str.contains("@", na=true), "Email"] = none
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 Dup.loc[Dup[~"Email"].str.contains("@", na=true), "Email"] = none
#
# NameError: name 'none' is not defined

# %%
List_names = ['Lilian', 'Adue', 'Iyke', 'Emem']

# %%
for i in List_names:
    print(i)
# Out:
# Lilian
# Adue
# Iyke
# Emem

# %%
Dup.fillna({"Score":})
